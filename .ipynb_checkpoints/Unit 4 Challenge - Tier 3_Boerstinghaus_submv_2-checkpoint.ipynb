# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.shape
# Out:
# (303, 49)

# %%
properties.dtypes
# Out:
# Unnamed: 0              datetime64[ns]
# City of London                  object
# Barking & Dagenham              object
# Barnet                          object
# Bexley                          object
# Brent                           object
# Bromley                         object
# Camden                          object
# Croydon                         object
# Ealing                          object
# Enfield                         object
# Greenwich                       object
# Hackney                         object
# Hammersmith & Fulham            object
# Haringey                        object
# Harrow                          object
# Havering                        object
# Hillingdon                      object
# Hounslow                        object
# Islington                       object
# Kensington & Chelsea            object
# Kingston upon Thames            object
# Lambeth                         object
# Lewisham                        object
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
prop_t = properties.transpose()

# %%
prop_t.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
prop_t.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
prop_t = prop_t.reset_index()

# %%
prop_t.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
prop_t.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# ...

# %%
# Assign first line as column headers
prop_t.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            293,     294,     295,     296,     297,     298,     299,     300,
#            301,     302],
#       dtype='object', length=304)

# %%
prop_t.columns = prop_t.iloc[0]

# %%
prop_t.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
prop_t.iloc[:7, :5]
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
# 5               Brent  E09000005              71306.6              72022.3
# 6             Bromley  E09000006              81671.5              81657.6
#
# 0  1995-03-01 00:00:00
# 0  1995-03-01 00:00:00
# 1              79120.7
# 2                51269
# 3              92247.5
# 4              64367.5
# 5              72015.8
# 6              81449.3

# %%
prop_t = prop_t.drop(0)

# %%
prop_t.iloc[:7, :5]
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
# 6             Bromley  E09000006             81671.5             81657.6
# 7              Camden  E09000007              120933              119509
#
# 0 1995-03-01 00:00:00
# 1             79120.7
# 2               51269
# 3             92247.5
# 4             64367.5
# 5             72015.8
# 6             81449.3
# 7              120282

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
prop_t = prop_t.rename(columns = {'Unnamed: 0': 'Borough', pd.NaT: 'ID'})

# %%
prop_t.head()
# Out:
# 0             Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %%
prop_t.iloc[:7, :5]
# Out:
# 0             Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
# 6             Bromley  E09000006             81671.5             81657.6
# 7              Camden  E09000007              120933              119509
#
# 0 1995-03-01 00:00:00
# 1             79120.7
# 2               51269
# 3             92247.5
# 4             64367.5
# 5             72015.8
# 6             81449.3
# 7              120282

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
#SYNTAX: pd.melt(df, id_vars =['Name'], value_vars =['Course']) 

clnprop = pd.melt(prop_t, id_vars = ['Borough', 'ID'])

# %%
clnprop.iloc[40:57:3,:15]
# Out:
#                Borough         ID          0    value
# 40       EAST MIDLANDS  E12000004 1995-01-01  45544.5
# 43              LONDON  E12000007 1995-01-01  74435.8
# 46         Unnamed: 47        NaN 1995-01-01      NaN
# 49  Barking & Dagenham  E09000002 1995-02-01  51085.8
# 52               Brent  E09000005 1995-02-01  72022.3
# 55             Croydon  E09000008 1995-02-01  68951.1

# %%
cleanprops = clnprop.rename(columns = {0: 'Dated', 'value': 'Avgprice'})

# %%
cleanprops.iloc[40:57:2, :6]
# Out:
#             Borough         ID      Dated Avgprice
# 40    EAST MIDLANDS  E12000004 1995-01-01  45544.5
# 42  EAST OF ENGLAND  E12000006 1995-01-01  56701.6
# 44       SOUTH EAST  E12000008 1995-01-01  64018.9
# 46      Unnamed: 47        NaN 1995-01-01      NaN
# 48   City of London  E09000001 1995-02-01  82202.8
# 50           Barnet  E09000003 1995-02-01  93190.2
# 52            Brent  E09000005 1995-02-01  72022.3
# 54           Camden  E09000007 1995-02-01   119509
# 56           Ealing  E09000009 1995-02-01  80897.1

# %%
cleanprops.shape
# Out:
# (14496, 4)

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
cleanprops.dtypes
# Out:
# Borough             object
# ID                  object
# Dated       datetime64[ns]
# Avgprice            object
# dtype: object

# %%
#to_numeric / as type...
cleanprops['Avgprice'] = cleanprops['Avgprice'].astype(float)

# %%
cleanprops.dtypes
# Out:
# Borough             object
# ID                  object
# Dated       datetime64[ns]
# Avgprice           float64
# dtype: object

# %%
cleanprops.count()
# Out:
# Borough     14496
# ID          13590
# Dated       14496
# Avgprice    13590
# dtype: int64

# %%
cleanprops.iloc[40:57:2, :6]
# Out:
#             Borough         ID      Dated      Avgprice
# 40    EAST MIDLANDS  E12000004 1995-01-01   45544.52227
# 42  EAST OF ENGLAND  E12000006 1995-01-01   56701.59610
# 44       SOUTH EAST  E12000008 1995-01-01   64018.87894
# 46      Unnamed: 47        NaN 1995-01-01           NaN
# 48   City of London  E09000001 1995-02-01   82202.77314
# 50           Barnet  E09000003 1995-02-01   93190.16963
# 52            Brent  E09000005 1995-02-01   72022.26197
# 54           Camden  E09000007 1995-02-01  119508.86220
# 56           Ealing  E09000009 1995-02-01   80897.06551

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
cleanprops['Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
cleanprops[cleanprops['Borough'] == 'Unnamed: 34'].head()
# Out:
#          Borough   ID      Dated  Avgprice
# 33   Unnamed: 34  NaN 1995-01-01       NaN
# 81   Unnamed: 34  NaN 1995-02-01       NaN
# 129  Unnamed: 34  NaN 1995-03-01       NaN
# 177  Unnamed: 34  NaN 1995-04-01       NaN
# 225  Unnamed: 34  NaN 1995-05-01       NaN

# %%
cleanprops[cleanprops['Borough'] == 'Unnamed: 37'].head()
# Out:
#          Borough   ID      Dated  Avgprice
# 36   Unnamed: 37  NaN 1995-01-01       NaN
# 84   Unnamed: 37  NaN 1995-02-01       NaN
# 132  Unnamed: 37  NaN 1995-03-01       NaN
# 180  Unnamed: 37  NaN 1995-04-01       NaN
# 228  Unnamed: 37  NaN 1995-05-01       NaN

# %%
dffreena_id = cleanprops[cleanprops['ID'].notna()]
dffreena_id.iloc[:57:6, :6]
# Out:
#                  Borough         ID      Dated      Avgprice
# 0         City of London  E09000001 1995-01-01   91448.98487
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 18             Islington  E09000019 1995-01-01   92516.48557
# 24                Newham  E09000025 1995-01-01   53539.31919
# 30        Waltham Forest  E09000031 1995-01-01   61319.44913
# 38            NORTH WEST  E12000002 1995-01-01   43958.48001
# 44            SOUTH EAST  E12000008 1995-01-01   64018.87894
# 51                Bexley  E09000004 1995-02-01   64787.92069
# 57               Enfield  E09000010 1995-02-01   73155.19746

# %%
dffreena_id.count()
# Out:
# Borough     13590
# ID          13590
# Dated       13590
# Avgprice    13590
# dtype: int64

# %%
dffreena_avp = cleanprops[cleanprops['Avgprice'].notna()]
dffreena_id.iloc[:57:6, :6]
# Out:
#                  Borough         ID      Dated      Avgprice
# 0         City of London  E09000001 1995-01-01   91448.98487
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 18             Islington  E09000019 1995-01-01   92516.48557
# 24                Newham  E09000025 1995-01-01   53539.31919
# 30        Waltham Forest  E09000031 1995-01-01   61319.44913
# 38            NORTH WEST  E12000002 1995-01-01   43958.48001
# 44            SOUTH EAST  E12000008 1995-01-01   64018.87894
# 51                Bexley  E09000004 1995-02-01   64787.92069
# 57               Enfield  E09000010 1995-02-01   73155.19746

# %%
dffreena_avp.count()
# Out:
# Borough     13590
# ID          13590
# Dated       13590
# Avgprice    13590
# dtype: int64

# %%
df2_free_na = cleanprops.dropna()
df2_free_na.iloc[:57:6, :6]
# Out:
#                  Borough         ID      Dated      Avgprice
# 0         City of London  E09000001 1995-01-01   91448.98487
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 18             Islington  E09000019 1995-01-01   92516.48557
# 24                Newham  E09000025 1995-01-01   53539.31919
# 30        Waltham Forest  E09000031 1995-01-01   61319.44913
# 38            NORTH WEST  E12000002 1995-01-01   43958.48001
# 44            SOUTH EAST  E12000008 1995-01-01   64018.87894
# 51                Bexley  E09000004 1995-02-01   64787.92069
# 57               Enfield  E09000010 1995-02-01   73155.19746

# %%
df2_free_na.count()
# Out:
# Borough     13590
# ID          13590
# Dated       13590
# Avgprice    13590
# dtype: int64

# %%
df2_free_na['Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
print(cleanprops.shape)
print(dffreena_avp.shape)
print(df2_free_na.shape)
# Out:
# (14496, 4)
# (13590, 4)
# (13590, 4)

# %%
non_boroughs = ['City of London', 'Inner London',
       'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
       'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
       'SOUTH EAST', 'SOUTH WEST', 'England']

# %%
df2_free_na[df2_free_na.Borough.isin(non_boroughs)]
# Out:
#                Borough         ID      Dated      Avgprice
# 0       City of London  E09000001 1995-01-01   91448.98487
# 34        Inner London  E13000001 1995-01-01   78251.97650
# 35        Outer London  E13000002 1995-01-01   72958.79836
# 37          NORTH EAST  E12000001 1995-01-01   42076.35411
# 38          NORTH WEST  E12000002 1995-01-01   43958.48001
# ...                ...        ...        ...           ...
# 14490  EAST OF ENGLAND  E12000006 2020-02-01  286869.06350
# 14491           LONDON  E12000007 2020-02-01  476972.07330
# 14492       SOUTH EAST  E12000008 2020-02-01  321329.36450
# 14493       SOUTH WEST  E12000009 2020-02-01  258043.97170
# 14495          England  E92000001 2020-02-01  246341.31270
#
# [3926 rows x 4 columns]

# %%
df2_free_na[~df2_free_na.Borough.isin(non_boroughs)]
# Out:
#                   Borough         ID      Dated      Avgprice
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# 5                 Bromley  E09000006 1995-01-01   81671.47692
# ...                   ...        ...        ...           ...
# 14476              Sutton  E09000029 2020-02-01  380197.65130
# 14477       Tower Hamlets  E09000030 2020-02-01  462323.47580
# 14478      Waltham Forest  E09000031 2020-02-01  441113.02350
# 14479          Wandsworth  E09000032 2020-02-01  600088.58990
# 14480         Westminster  E09000033 2020-02-01  975090.95900
#
# [9664 rows x 4 columns]

# %%
df = df2_free_na[~df2_free_na.Borough.isin(non_boroughs)]

# %%
df.head()
# Out:
#               Borough         ID      Dated     Avgprice
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698
# 5             Bromley  E09000006 1995-01-01  81671.47692

# %%
df.dtypes
# Out:
# Borough             object
# ID                  object
# Dated       datetime64[ns]
# Avgprice           float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
barnet_prices = df[df['Borough'] == 'Barnet']

# %%
ax = barnet_prices.plot(kind='line', x='Dated', y='Avgprice')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df['Year'] = df['Dated'].apply(lambda t: t.year)
# Out:
# C:\Users\Bo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.tail()
# Out:
#               Borough         ID      Dated     Avgprice  Year
# 14476          Sutton  E09000029 2020-02-01  380197.6513  2020
# 14477   Tower Hamlets  E09000030 2020-02-01  462323.4758  2020
# 14478  Waltham Forest  E09000031 2020-02-01  441113.0235  2020
# 14479      Wandsworth  E09000032 2020-02-01  600088.5899  2020
# 14480     Westminster  E09000033 2020-02-01  975090.9590  2020

# %%
dfg = df.groupby(by=['Borough', 'Year']).mean()
dfg.sample(10)
# Out:
#                                 Avgprice
# Borough              Year
# Greenwich            2013  253399.260875
# Sutton               2004  201829.271908
# Westminster          2012  696926.040917
# Barnet               2018  533266.534055
# Richmond upon Thames 2000  227866.164158
# Ealing               2011  302306.913175
# Bromley              2020  436590.691950
# Camden               2020  796798.853200
# Waltham Forest       2006  209707.758583
# Harrow               2010  292166.041742

# %%
dfg = dfg.reset_index()
dfg.head()
# Out:
#               Borough  Year      Avgprice
# 0  Barking & Dagenham  1995  51817.969390
# 1  Barking & Dagenham  1996  51718.192690
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %%
barnet_prices = dfg[dfg['Borough'] == 'Barnet']
ax = barnet_prices.plot(kind='line', x='Year', y='Avgprice')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
cnk_prices = dfg[dfg['Borough'] == 'Kensington & Chelsea']
ax = cnk_prices.plot(kind='line', x='Year', y='Avgprice')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
ww_prices = dfg[dfg['Borough'] == 'Wentsworth']
ax = ww_prices.plot(kind='scatter', x='Year', y='Avgprice')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# see 3.3 above: models show price increase therefore division other way round
def ratio_18_98(d):
    avg_1998 = float(d['Avgprice'][d['Year']==1998])
    avg_2018 = float(d['Avgprice'][d['Year']==2018])
    ratio_18_98 = avg_2018 / avg_1998
    return ratio_18_98

# %%
def ratio_19_99(d):
    avg_1999 = float(d['Avgprice'][d['Year']==1999])
    avg_2019 = float(d['Avgprice'][d['Year']==2019])
    ratio_19_99 = avg_2019 / avg_1999
    return ratio_19_99

# %%
def sum_18_98(d):
    avg_1998 = float(d['Avgprice'][d['Year']==1998])
    avg_2018 = float(d['Avgprice'][d['Year']==2018])
    diff_18_98 = avg_2018 - avg_1998
    return avg_2018, avg_1998, diff_18_98

# %%
def sum_19_99(d):
    avg_1999 = float(d['Avgprice'][d['Year']==1999])
    avg_2019 = float(d['Avgprice'][d['Year']==2019])
    diff_19_99 = avg_2019 - avg_1999
    return avg_2019, avg_1999, diff_19_99

# %%
ratio_18_98(dfg[dfg['Borough']=='Hillingdon'])
# Out:
# 4.2002730803844575

# %%
ratio_19_99(dfg[dfg['Borough']=='Sutton'])
# Out:
# 3.6913508169650884

# %%
sum_18_98(dfg[dfg['Borough']=='Hillingdon'])
# Out:
# (410266.07901, 97676.04895166667, 312590.0300583333)

# %%
sum_19_99(dfg[dfg['Borough']=='Sutton'])
# Out:
# (372345.8692916666, 100869.81372249998, 271476.0555691666)

# %%
final = {}

# %%
for b in dfg['Borough'].unique():
    borough = dfg[dfg['Borough'] == b]
    final[b] = ratio_18_98(borough), ratio_19_99(borough)
print(final)
# Out:
# {'Barking & Dagenham': (4.89661861291754, 4.578469314778293), 'Barnet': (4.358195917538044, 3.8229756807882107), 'Bexley': (4.248977046127877, 3.885841564351589), 'Brent': (4.8945544971392865, 4.2305991550914825), 'Bromley': (4.0947846853338765, 3.6145310059845985), 'Camden': (4.935353408884261, 4.402770257137366), 'Croydon': (4.201100280024767, 3.7610567362898646), 'Ealing': (4.311450902121834, 3.743384960365388), 'Enfield': (4.26347158349581, 3.8518261020149076), 'Greenwich': (4.763036347329193, 4.321825706783743), 'Hackney': (6.198285561008662, 5.258154128080544), 'Hammersmith & Fulham': (4.137798101936229, 3.627552600410921), 'Haringey': (5.134624964136042, 4.5624937378537584), 'Harrow': (4.0591964329643195, 3.545224110575635), 'Havering': (4.325230371335308, 3.925011453658359), 'Hillingdon': (4.2002730803844575, 3.712899531863647), 'Hounslow': (3.976409106143329, 3.5801181495638104), 'Islington': (4.844048012802298, 4.082243972446511), 'Kensington & Chelsea': (5.082465066092464,
# ...

# %%
finalsums_18_98 = {}

# %%
for b in dfg['Borough'].unique():
    borough = dfg[dfg['Borough'] == b]
    finalsums_18_98[b] = sum_18_98(borough)
print(finalsums_18_98)
# Out:
# {'Barking & Dagenham': (295196.67361166666, 60285.821083333336, 234910.85252833331), 'Barnet': (533266.534055, 122359.46803333331, 410907.06602166675), 'Bexley': (342603.6056541667, 80632.02082166668, 261971.58483250003), 'Brent': (492845.37125250004, 100692.59041666666, 392152.7808358334), 'Bromley': (443409.985635, 108286.52046666665, 335123.4651683333), 'Camden': (842410.4093608333, 170688.97393333333, 671721.4354275), 'Croydon': (370298.5433200001, 88143.22883, 282155.31449000014), 'Ealing': (480050.54456083337, 111343.15465, 368707.3899108334), 'Enfield': (396631.71780166664, 93030.22432166668, 303601.49347999995), 'Greenwich': (388344.32512583333, 81532.93336583335, 306811.39175999997), 'Hackney': (544640.4750275, 87869.53580416668, 456770.93922333326), 'Hammersmith & Fulham': (725525.3311399999, 175340.92125, 550184.4098899999), 'Haringey': (551560.64401, 107419.85010833334, 444140.7939016667), 'Harrow': (465907.4632525, 114778.25006666667, 351129.2131858333), 'Havering': (370
# ...

# %%
finalsums_19_99 = {}

# %%
for b in dfg['Borough'].unique():
    borough = dfg[dfg['Borough'] == b]
    finalsums_19_99[b] = sum_19_99(borough)
print(finalsums_19_99)
# Out:
# {'Barking & Dagenham': (299069.89395, 65320.934440833335, 233748.95950916666), 'Barnet': (519941.94210833334, 136004.51206666665, 383937.4300416667), 'Bexley': (337204.45531666663, 86777.71590333334, 250426.7394133333), 'Brent': (474493.29700833344, 112157.46980833334, 362335.8272000001), 'Bromley': (436903.46986666665, 120874.17956666666, 316029.2903), 'Camden': (841328.4388916668, 191090.69739166668, 650237.7415000001), 'Croydon': (365474.3805083334, 97173.32285416666, 268301.0576541667), 'Ealing': (472708.4475416667, 126278.34234166665, 346430.10520000005), 'Enfield': (392836.164175, 101986.99364166665, 290849.1705333333), 'Greenwich': (392763.76764166664, 90879.13171166666, 301884.63593), 'Hackney': (554908.6178666666, 105532.96924166667, 449375.648625), 'Hammersmith & Fulham': (721524.4935500001, 198901.18022500002, 522623.3133250001), 'Haringey': (547880.04925, 120083.46328333333, 427796.5859666667), 'Harrow': (449135.850925, 126687.57655833334, 322448.2743666666), 'Havering': 
# ...

# %%
df_ratios = pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
# 1            4.578469  3.822976  3.885842  4.230599  3.614531  4.402770
#
#     Croydon    Ealing   Enfield  Greenwich  ...    Merton   Newham  Redbridge  \
# 0  4.201100  4.311451  4.263472   4.763036  ...  4.741273  5.30539   4.471182
# 1  3.761057  3.743385  3.851826   4.321826  ...  4.156800  4.87680   4.008479
#
#    Richmond upon Thames  Southwark    Sutton  Tower Hamlets  Waltham Forest  \
# 0              4.005162   5.516485  4.118523       4.626701        5.834756
# 1              3.578798   4.526851  3.691351       3.881920        5.136652
#
#    Wandsworth  Westminster
# 0    4.757709     5.353565
# 1    4.052667     4.460550
#
# [2 rows x 32 columns]

# %%
transdf = df_ratios.transpose()
transdf.iloc[:31:3,:]
# Out:
#                              0         1
# Barking & Dagenham    4.896619  4.578469
# Brent                 4.894554  4.230599
# Croydon               4.201100  3.761057
# Greenwich             4.763036  4.321826
# Haringey              5.134625  4.562494
# Hillingdon            4.200273  3.712900
# Kensington & Chelsea  5.082465  4.005551
# Lewisham              5.449221  4.833663
# Redbridge             4.471182  4.008479
# Sutton                4.118523  3.691351
# Wandsworth            4.757709  4.052667

# %%
transdf = transdf.reset_index()
transdf.head()
# Out:
#                 index         0         1
# 0  Barking & Dagenham  4.896619  4.578469
# 1              Barnet  4.358196  3.822976
# 2              Bexley  4.248977  3.885842
# 3               Brent  4.894554  4.230599
# 4             Bromley  4.094785  3.614531

# %%
transdf.rename(columns={'index':'Borough', 0:'Ratio_18_98', 1:'Ratio_19_99'}, inplace=True)
transdf.tail()
# Out:
#            Borough  Ratio_18_98  Ratio_19_99
# 27          Sutton     4.118523     3.691351
# 28   Tower Hamlets     4.626701     3.881920
# 29  Waltham Forest     5.834756     5.136652
# 30      Wandsworth     4.757709     4.052667
# 31     Westminster     5.353565     4.460550

# %%
transdf.iloc[:31:3,:]
# Out:
#                  Borough  Ratio_18_98  Ratio_19_99
# 0     Barking & Dagenham     4.896619     4.578469
# 3                  Brent     4.894554     4.230599
# 6                Croydon     4.201100     3.761057
# 9              Greenwich     4.763036     4.321826
# 12              Haringey     5.134625     4.562494
# 15            Hillingdon     4.200273     3.712900
# 18  Kensington & Chelsea     5.082465     4.005551
# 21              Lewisham     5.449221     4.833663
# 24             Redbridge     4.471182     4.008479
# 27                Sutton     4.118523     3.691351
# 30            Wandsworth     4.757709     4.052667

# %%
top5_18_98 = transdf.sort_values(by='Ratio_18_98',ascending=False)
print(top5_18_98.head())
# Out:
#            Borough  Ratio_18_98  Ratio_19_99
# 10         Hackney     6.198286     5.258154
# 29  Waltham Forest     5.834756     5.136652
# 26       Southwark     5.516485     4.526851
# 21        Lewisham     5.449221     4.833663
# 31     Westminster     5.353565     4.460550

# %%
top5_19_99 = transdf.sort_values(by='Ratio_19_99',ascending=False)
print(top5_19_99.head())
# Out:
#                Borough  Ratio_18_98  Ratio_19_99
# 10             Hackney     6.198286     5.258154
# 29      Waltham Forest     5.834756     5.136652
# 23              Newham     5.305390     4.876800
# 21            Lewisham     5.449221     4.833663
# 0   Barking & Dagenham     4.896619     4.578469

# %%
df_sums_18_98 = pd.DataFrame(finalsums_18_98)

# %%
df_sums_18_98.head()
# Out:
#    Barking & Dagenham         Barnet         Bexley          Brent  \
# 0       295196.673612  533266.534055  342603.605654  492845.371253
# 1        60285.821083  122359.468033   80632.020822  100692.590417
# 2       234910.852528  410907.066022  261971.584833  392152.780836
#
#          Bromley         Camden       Croydon         Ealing        Enfield  \
# 0  443409.985635  842410.409361  370298.54332  480050.544561  396631.717802
# 1  108286.520467  170688.973933   88143.22883  111343.154650   93030.224322
# 2  335123.465168  671721.435428  282155.31449  368707.389911  303601.493480
#
#        Greenwich  ...         Merton         Newham      Redbridge  \
# 0  388344.325126  ...  512293.894570  359022.512777  422591.065915
# 1   81532.933366  ...  108049.855117   67671.270763   94514.395822
# 2  306811.391760  ...  404244.039453  291351.242014  328076.670093
#
#    Richmond upon Thames      Southwark         Sutton  Tower Hamlets  \
# ...

# %%
transsums_18_98 = df_sums_18_98.transpose()
transsums_18_98.iloc[:31:5,:]
# Out:
#                                   0              1              2
# Barking & Dagenham    295196.673612   60285.821083  234910.852528
# Camden                842410.409361  170688.973933  671721.435428
# Hackney               544640.475027   87869.535804  456770.939223
# Hillingdon            410266.079010   97676.048952  312590.030058
# Lambeth               511536.396992  103179.118943  408357.278048
# Richmond upon Thames  652665.426320  162956.066025  489709.360295
# Wandsworth            596649.139044  125406.807233  471242.331811

# %%
transsums_18_98 = transsums_18_98.reset_index()
transsums_18_98.head()
# Out:
#                 index              0              1              2
# 0  Barking & Dagenham  295196.673612   60285.821083  234910.852528
# 1              Barnet  533266.534055  122359.468033  410907.066022
# 2              Bexley  342603.605654   80632.020822  261971.584833
# 3               Brent  492845.371253  100692.590417  392152.780836
# 4             Bromley  443409.985635  108286.520467  335123.465168

# %%
transsums_18_98.rename(columns={'index':'Borough', 0:'AvgSum_18', 1:'AvgSum_98', 2:'SumDif_18_98'}, inplace=True)
transsums_18_98.tail()
# Out:
#            Borough     AvgSum_18      AvgSum_98   SumDif_18_98
# 27          Sutton  3.792626e+05   92087.045921  287175.534661
# 28   Tower Hamlets  4.465006e+05   96505.166407  349995.387378
# 29  Waltham Forest  4.408594e+05   75557.474132  365301.936996
# 30      Wandsworth  5.966491e+05  125406.807233  471242.331811
# 31     Westminster  1.020025e+06  190531.949942  829493.303452

# %%
transsums_18_98.tail()
# Out:
#            Borough     AvgSum_18      AvgSum_98   SumDif_18_98
# 27          Sutton  3.792626e+05   92087.045921  287175.534661
# 28   Tower Hamlets  4.465006e+05   96505.166407  349995.387378
# 29  Waltham Forest  4.408594e+05   75557.474132  365301.936996
# 30      Wandsworth  5.966491e+05  125406.807233  471242.331811
# 31     Westminster  1.020025e+06  190531.949942  829493.303452

# %%
top5sums_18_98 = transsums_18_98.sort_values(by='AvgSum_18',ascending=False)
print(top5sums_18_98.head())
# Out:
#                  Borough     AvgSum_18      AvgSum_98  SumDif_18_98
# 18  Kensington & Chelsea  1.363880e+06  268350.122142  1.095530e+06
# 31           Westminster  1.020025e+06  190531.949942  8.294933e+05
# 5                 Camden  8.424104e+05  170688.973933  6.717214e+05
# 11  Hammersmith & Fulham  7.255253e+05  175340.921250  5.501844e+05
# 25  Richmond upon Thames  6.526654e+05  162956.066025  4.897094e+05

# %%
top5_sumdif_18_98 = transsums_18_98.sort_values(by='SumDif_18_98',ascending=False)
print(top5_sumdif_18_98.head())
# Out:
#                  Borough     AvgSum_18      AvgSum_98  SumDif_18_98
# 18  Kensington & Chelsea  1.363880e+06  268350.122142  1.095530e+06
# 31           Westminster  1.020025e+06  190531.949942  8.294933e+05
# 5                 Camden  8.424104e+05  170688.973933  6.717214e+05
# 11  Hammersmith & Fulham  7.255253e+05  175340.921250  5.501844e+05
# 17             Islington  6.498241e+05  134148.973300  5.156751e+05

# %%
df_sums_19_99 = pd.DataFrame(finalsums_19_99)

# %%
df_sums_19_99.head()
# Out:
#    Barking & Dagenham         Barnet         Bexley          Brent  \
# 0       299069.893950  519941.942108  337204.455317  474493.297008
# 1        65320.934441  136004.512067   86777.715903  112157.469808
# 2       233748.959509  383937.430042  250426.739413  362335.827200
#
#          Bromley         Camden        Croydon         Ealing        Enfield  \
# 0  436903.469867  841328.438892  365474.380508  472708.447542  392836.164175
# 1  120874.179567  191090.697392   97173.322854  126278.342342  101986.993642
# 2  316029.290300  650237.741500  268301.057654  346430.105200  290849.170533
#
#        Greenwich  ...         Merton         Newham      Redbridge  \
# 0  392763.767642  ...  506719.665617  363446.280408  412634.653817
# 1   90879.131712  ...  121901.372575   74525.568363  102940.450633
# 2  301884.635930  ...  384818.293042  288920.712046  309694.203183
#
#    Richmond upon Thames      Southwark         Sutton  Tower Hamlets  \
# ...

# %%
transsums_19_99 = df_sums_19_99.transpose()
transsums_19_99.iloc[:31:5,:]
# Out:
#                                   0              1              2
# Barking & Dagenham    299069.893950   65320.934441  233748.959509
# Camden                841328.438892  191090.697392  650237.741500
# Hackney               554908.617867  105532.969242  449375.648625
# Hillingdon            404429.143742  108925.420758  295503.722983
# Lambeth               508348.568775  116616.291725  391732.277050
# Richmond upon Thames  650526.416100  181772.319642  468754.096458
# Wandsworth            589013.797742  145339.809767  443673.987975

# %%
transsums_19_99 = transsums_19_99.reset_index()
transsums_19_99.head()
# Out:
#                 index              0              1              2
# 0  Barking & Dagenham  299069.893950   65320.934441  233748.959509
# 1              Barnet  519941.942108  136004.512067  383937.430042
# 2              Bexley  337204.455317   86777.715903  250426.739413
# 3               Brent  474493.297008  112157.469808  362335.827200
# 4             Bromley  436903.469867  120874.179567  316029.290300

# %%
transsums_19_99.rename(columns={'index':'Borough', 0:'AvgSum_19', 1:'AvgSum_99', 2:'SumDif_19_99'}, inplace=True)
transsums_19_99.tail()
# Out:
#            Borough      AvgSum_19      AvgSum_99   SumDif_19_99
# 27          Sutton  372345.869292  100869.813722  271476.055569
# 28   Tower Hamlets  438793.954325  113035.289367  325758.664958
# 29  Waltham Forest  430562.310358   83821.587936  346740.722423
# 30      Wandsworth  589013.797742  145339.809767  443673.987975
# 31     Westminster  954748.119558  214042.702508  740705.417050

# %%
transsums_19_99.iloc[:31:5,:]
# Out:
#                  Borough      AvgSum_19      AvgSum_99   SumDif_19_99
# 0     Barking & Dagenham  299069.893950   65320.934441  233748.959509
# 5                 Camden  841328.438892  191090.697392  650237.741500
# 10               Hackney  554908.617867  105532.969242  449375.648625
# 15            Hillingdon  404429.143742  108925.420758  295503.722983
# 20               Lambeth  508348.568775  116616.291725  391732.277050
# 25  Richmond upon Thames  650526.416100  181772.319642  468754.096458
# 30            Wandsworth  589013.797742  145339.809767  443673.987975

# %%
top5sums_19_99 = transsums_19_99.sort_values(by='AvgSum_19',ascending=False)
print(top5sums_19_99.head())
# Out:
#                  Borough     AvgSum_19      AvgSum_99   SumDif_19_99
# 18  Kensington & Chelsea  1.247550e+06  311455.366475  936095.008358
# 31           Westminster  9.547481e+05  214042.702508  740705.417050
# 5                 Camden  8.413284e+05  191090.697392  650237.741500
# 11  Hammersmith & Fulham  7.215245e+05  198901.180225  522623.313325
# 25  Richmond upon Thames  6.505264e+05  181772.319642  468754.096458

# %%
top5_sumdif_19_99 = transsums_19_99.sort_values(by='SumDif_19_99',ascending=False)
print(top5_sumdif_19_99.head())
# Out:
#                  Borough     AvgSum_19      AvgSum_99   SumDif_19_99
# 18  Kensington & Chelsea  1.247550e+06  311455.366475  936095.008358
# 31           Westminster  9.547481e+05  214042.702508  740705.417050
# 5                 Camden  8.413284e+05  191090.697392  650237.741500
# 11  Hammersmith & Fulham  7.215245e+05  198901.180225  522623.313325
# 17             Islington  6.351553e+05  155589.737392  479565.530250

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [raw]
# Boerstinghaus_London Answers
#
# London is divided into 32 boroughs. Objective of the task was to find out which boroughs have seen the greatest increase in house prices on average over the last two decades.
#
# 1.	Between 1998 and 2018 the following boroughs: (a) 'Hackney' (6.19832), (b) Waltham Forrest' (5.83479) and (c) 'Southwark' (5.51649) saw the highest increase in growth ratio in house prices as indicated.
# In the period between 1999 and 2019 boroughs (a): (5.25820) and (b): (5.13668) kept places, but (d) Newham (4.87683) occupied the third place.
#
# Nevertheless with regard to year 2018 [and 2019] the highest average prices (in GBP) for houses were paid in these London boroughs: (x) 'Kensington and Chelsea' (1.363 Mio., [ 1.248 Mio.]), (y) 'Westminster' (1.020 Mio., [0.955 Mio.]) and (z) 'Camden' (0.842 Mio., [0.841 Mio.]). Making these the most expensive boroughs with the highest increase in sums (rounded in GBP) to be paid between 1998 / [1999] and 2018 / [2019]:
# (a): 1.096 Mio. [0.936 Mio.], (b): 0.829 Mio. [0.741 Mio.], (c): 0.672 Mio. [0.650 Mio.].
#
# 2.	How did I arrive at this conclusion:
# By importing the data collection from London datastore, selecting the data for London boroughs (pls. see comment in 3.), correct indexing so that the intersection of rows and columns showed values for borough per date. Melting the frames to enhance readability and simplify grouping average payments per month to average payment per year and dividing generated sums of the latter year (2018) through the average sum of the start year (1998) as sums were increasing throughout the years to find the growth factor. Sorting these data to get the name of the top 3 boroughs. To find out about the increase in sums paid per borough I subtracted average sums paid in 1998 (1999) by average sums paid in 2018 (2019).
#
# 3.	Main challenges encountered:
# Source of investigation, i.e. data collection from London datastore, includes also data for other areas apart from the 32 boroughs of London.
# Excluded from the investigation were data for: 'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England', as well as for 'City of London', which was included in the boroughs section.
#
# Defining the ratio as a factor to show increase in prices required a change in the proposed procedure: if you follow the way as described it showed the value of the starting year compared to the ending year of evaluation, which showed the initial ratio compared to the more actual values, but as prices increased during the years growth is indicated by dividing sums of the actual years through those of end 90's. I oversaw this in the first paper I submitted, leading to an incorrect conclusion.
#
# The grouping of years should be done more elegantly, as the proposed way to " .apply(lambda t: t.year)" produces a 'SettingWithCopyWarning' but nevertheless it works. I hope to find a more elegant solution during the next exercises.
# To find an answer to the question, which boroughs were the most expensive ones payments as such needed to be investigated apart from the ratio.
#
# 4.	To be investigated further: as the data from 2019 are closer to the actual date I also used these in a comparison with 1999 for another two decade evaluation.
# It would also be possible to do a survey on increases for a 25 year period as complete data sets for years from 1995 to 2019 exist.
#
#
# Anke Börstinghaus
# Dortmund
# 2020-05-18
